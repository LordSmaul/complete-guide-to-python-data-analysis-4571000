#              145 File(s)     27,492,570 bytes
#                2 Dir(s)  916,753,997,824 bytes free

# %%
open('names/yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21859\n',
#  'Isabella,F,19928\n',
#  'Emma,F,18820\n',
#  'Olivia,F,17333\n',
#  'Ava,F,15514\n',
#  'Emily,F,14275\n',
#  'Abigail,F,13261\n',
#  'Madison,F,12402\n',
#  'Mia,F,11540\n',
#  'Chloe,F,11006\n']

# %%
pd.read_csv('names/yob2023.txt', engine='pyarrow', dtype_backend='pyarrow')
# Out:
#           Olivia  F  15270
# 0           Emma  F  13527
# 1      Charlotte  F  12596
# 2         Amelia  F  12311
# 3         Sophia  F  11944
# 4            Mia  F  11359
# ...          ... ..    ...
# 31676      Zyell  M      5
# 31677       Zyen  M      5
# 31678     Zymirr  M      5
# 31679     Zyquan  M      5
# 31680      Zyrin  M      5
#
# [31681 rows x 3 columns]

# %%
pd.read_csv('names/yob2023.txt', names=['name', 'sex', 'number'],
            engine='pyarrow', dtype_backend='pyarrow')
# Out:
#             name sex  number
# 0         Olivia   F   15270
# 1           Emma   F   13527
# 2      Charlotte   F   12596
# 3         Amelia   F   12311
# 4         Sophia   F   11944
# ...          ...  ..     ...
# 31677      Zyell   M       5
# 31678       Zyen   M       5
# 31679     Zymirr   M       5
# 31680     Zyquan   M       5
# 31681      Zyrin   M       5
#
# [31682 rows x 3 columns]

# %%
pd.read_csv('names/yob2011.txt', names=['name', 'sex', 'number'],
            engine='pyarrow', dtype_backend='pyarrow').assign(year=2011)
# Out:
#            name sex  number  year
# 0        Sophia   F   21859  2011
# 1      Isabella   F   19928  2011
# 2          Emma   F   18820  2011
# 3        Olivia   F   17333  2011
# 4           Ava   F   15514  2011
# ...         ...  ..     ...   ...
# 33936     Zylar   M       5  2011
# 33937     Zylas   M       5  2011
# 33938     Zyran   M       5  2011
# 33939   Zyshawn   M       5  2011
# 33940  Zytavion   M       5  2011
#
# [33941 rows x 4 columns]

# %%
allyears = pd.concat(pd.read_csv(f'names/yob{year}.txt', names=['name', 'sex', 'number'],
                                 engine='pyarrow', dtype_backend='pyarrow').assign(year=year)
                     for year in range(1880, 2024))

# %%
allyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2117219 entries, 0 to 31681
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   name    string[pyarrow]
#  1   sex     string[pyarrow]
#  2   number  int64[pyarrow]
#  3   year    int64
# dtypes: int64(1), int64[pyarrow](1), string[pyarrow](2)
# memory usage: 79.1 MB

# %%
allyears = allyears.convert_dtypes(dtype_backend='pyarrow')

# %%
allyears.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2117219 entries, 0 to 31681
# Data columns (total 4 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   name    string[pyarrow]
#  1   sex     string[pyarrow]
#  2   number  int64[pyarrow]
#  3   year    int64[pyarrow]
# dtypes: int64[pyarrow](2), string[pyarrow](2)
# memory usage: 79.1 MB

# %%
allyears.to_feather('allyears.feather')
